# %%
import tsfresh
from tsfresh import feature_selection
from tsfresh import extract_features, select_features
import os
import warnings
from abc import ABC
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset
from tqdm.notebook import tqdm
from collections import Counter
import torch.nn as nn
import gc
import time
import torch
import numpy as np
import random
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
import math
import pywt
from math import log
from tsfresh.feature_extraction import MinimalFCParameters,EfficientFCParameters
from tsfresh import feature_extraction
from tsfresh import extract_features
from tsfresh import extract_features, select_features
from tsfresh.utilities.dataframe_functions import impute
from sklearn.decomposition import PCA
import tsfresh
from tsfresh import feature_selection
from tsfresh import extract_features, select_features
from utilities import *
from scipy.signal import savgol_filter

# %% [markdown]
# # 读取原始数据(以某个文件为例)

# %%
DATA_PATH = "../Datasets/sit-ups/"
attribute = ["Time","og1","og2","og3","ag1","ag2","ag3","ac1","ac2","ac3"]
sit_up_1 = pd.read_csv(DATA_PATH + "lefthand_normal_2.csv",names=attribute, header=None)

# %%
sit_up_1.head()
# Out:
#       Time       og1       og2  og3         ag1       ag2         ag3  \
# 0  0.02334  0.000000  0.000000  0.0 -171.079102  3.878174 -136.197510
# 1  0.02334 -0.549316 -0.488281  0.0 -171.084595  3.883667 -136.197510
# 2  0.02334 -0.427246 -0.549316  0.0 -171.090088  3.889160 -136.197510
# 3  0.02334 -0.427246 -0.549316  0.0 -171.095581  3.894653 -136.197510
# 4  0.02334 -0.305176 -0.732422  0.0 -171.101074  3.900146 -136.192017
#
#         ac1       ac2       ac3
# 0  0.000000  0.000000  0.000000
# 1 -0.066406 -0.153809 -0.989258
# 2 -0.066406 -0.152832 -0.986816
# 3 -0.066406 -0.152832 -0.986816
# 4 -0.066895 -0.152344 -0.986328

# %% [markdown]
# # 切割

# %%
# 第一个样本为例

# %%
m1 = get_major_frequency(sit_up_1.iloc[:,1:])
plt.plot(m1)

# %%
tmp_smooth = savgol_filter(m1,403,3) #501是平滑参数 越大平滑越多
plt.plot(tmp_smooth)

# %%
start_list3,end_list3 = get_raw_start_end_list(tmp_smooth,lim_a=-0.0001,lim_b=0.0001)
start_list_edit3 = get_start_edit(start_list3)
end_listd_edit3 = get_end_edit(end_list3)

# %%
end_list3
# Out:
# array([1047, 1048, 1049, 1050, 1051, 1052, 1457, 1458, 1459, 1460, 1461,
#        1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472,
#        1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483,
#        1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494,
#        1495, 1496, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939,
#        1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950,
#        1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 2411, 2412, 2413, 2414, 2415,
#        2416, 2417, 2418, 2419, 2420, 2421, 2422, 2423, 2424, 2425, 2426,
#        2427, 2428, 2429, 2430, 2431, 2432, 2433, 2434, 2435, 2436, 2437,
#        2438, 2439, 2440, 2441, 2442, 2443, 2444, 2445, 2446, 2447, 2448,
#        2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2459,
#        2460, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905, 2906,
#        2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915, 2916, 2917,
#        2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928,
#        2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936, 2937, 2938, 2939,
#        2940, 2941, 2942, 2943, 2944, 2945, 2946, 3383, 3384, 3385, 3386,
#        3387, 3388, 3389, 3390, 3391, 3392, 3393, 3394, 3395, 3396, 3397,
#        3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408,
#        3409, 3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419,
#        3420, 3421, 3422, 3423, 3424, 3425, 3426, 3427, 3428, 3429, 3430,
#        3431, 3432, 3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952,
#        3953, 3954, 3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963,
#        3964, 3965, 3966, 3967, 3968, 3969, 3970, 3971, 3972, 3973, 3974,
#        3975, 3976, 3977, 3978, 3979, 3980, 3981, 3982, 3983, 3984, 3985,
#        3986, 3987, 3988, 3989, 3990, 3991, 3992, 3993, 4459, 4460, 4461,
#        4462, 4463, 4464, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4472,
#        4473, 4474, 4475, 4476, 4477, 4478, 4479, 4480, 4943, 4944, 4945,
#        4946, 4947, 4948, 4949, 4950, 4951, 4952, 4953, 4954, 4955, 4956,
#        4957, 4958, 4959, 4960, 4961, 4962, 4963, 4964, 4965, 4966, 4967,
#        4968, 4969, 4970, 4971, 4972, 4973, 4974, 4975, 4976, 4977, 4978,
#        4979, 4980, 4981, 4982, 4983, 4984, 4985, 4986, 4987, 4988, 4989,
#        4990, 4991, 4992, 5480, 5481, 5482, 5483, 5484, 5485, 5486, 5487,
#        5488, 5489, 5490, 5491, 5492, 5493, 5494, 5495, 5496, 5497, 5498,
#        5499, 5500, 5501, 5502, 5503, 5504, 5505, 5506, 5507, 5508, 5509,
#        5510, 5511, 5512, 5513, 5514, 5515, 5516, 5517, 5518, 5519, 5520,
#        5521, 5522, 5523, 5524, 5525, 5526, 5527, 5528, 5529])

# %%
plt.figure(figsize=(30,6))
#plt.plot(d_signal,"pink")
plt.plot(tmp_smooth)
plt.vlines(start_list_edit3,np.min(m1),np.max(m1),color = "g",label='start')
plt.vlines(end_listd_edit3,np.min(m1),np.max(m1),color = "red",label = 'end')
plt.legend(fontsize = 20)
plt.title("normal",fontsize = 20)
plt.show()

# %%
#如何切割
assert len(start_list_edit3) == len(end_listd_edit3)
slice_list = []
for i in range(len(start_list_edit3)):
    nb1 = sit_up_1.iloc[start_list_edit3[i]:end_listd_edit3[i]]
    nb1_ = nb1.copy()
    nb1_.loc[:,"Time"] = np.arange(1,nb1.shape[0]+1)
    nb1_.reset_index(drop = True)
    slice_list.append(nb1_)

sliced_sample = pd.concat(slice_list)
sliced_sample["label"] = 0
sliced_sample
# Out:
#       Time       og1       og2       og3         ag1        ag2         ag3  \
# 605      1  0.000000 -0.183105  0.000000 -166.173706   3.927612  106.968384
# 606      2  0.000000 -0.183105  0.000000 -166.173706   3.927612  106.968384
# 607      3  0.000000 -0.122070  0.000000 -166.173706   3.933105  106.973877
# 608      4  0.000000 -0.122070  0.000000 -166.173706   3.933105  106.973877
# 609      5  0.000000 -0.061035  0.000000 -166.173706   3.933105  106.973877
# ...    ...       ...       ...       ...         ...        ...         ...
# 4886   371 -2.441406  0.488281  0.122070 -162.883301  17.330933  138.273926
# 4887   372 -3.295898  2.746582 -0.244141 -162.927246  17.319946  138.114624
# 4888   373 -3.295898  2.746582 -0.244141 -162.982178  17.297974  137.960815
# 4889   374 -2.136230  1.647949 -0.427246 -163.026123  17.276001  137.807007
# 4890   375 -2.136230  1.647949 -0.427246 -163.064575  17.265015  137.658691
#
#            ac1       ac2       ac3  label
# 605  -0.067383 -0.237305 -0.968750      0
# 606  -0.067383 -0.237305 -0.968750      0
# 607  -0.066406 -0.238281 -0.968750      0
# 608  -0.066406 -0.238281 -0.968750      0
# 609  -0.066895 -0.237793 -0.967285      0
# ...        ...       ...       ...    ...
# 4886 -0.297363 -0.230957 -0.910645      0
# 4887 -0.297363 -0.229980 -0.925781      0
# 4888 -0.297363 -0.229980 -0.925781      0
# 4889 -0.294922 -0.230469 -0.943848      0
# 4890 -0.294922 -0.230469 -0.943848      0
#
# [3615 rows x 11 columns]

# %% [markdown]
# # 定义一个函数，输入为地址，再获得sliced_sample

# %%
def raw_csv_to_sliced_sample(file,label,DATA_PATH = "../Datasets/sit-ups/"):
    attribute = ["Time","og1","og2","og3","ag1","ag2","ag3","ac1","ac2","ac3"]
    sit_up_1 = pd.read_csv(DATA_PATH + file,
                           names=attribute, header=None)
    m1 = get_major_frequency(sit_up_1.iloc[:,1:])
    tmp_smooth = savgol_filter(m1,403,3)
    start_list3,end_list3 = get_raw_start_end_list(tmp_smooth,lim_a=-0.0001,lim_b=0.0001)
    start_list_edit3 = get_start_edit(start_list3)
    end_listd_edit3 = get_end_edit(end_list3)
    assert len(start_list_edit3) == len(end_listd_edit3)
    slice_list = []
    sit_up_1.iloc[:,1:] = sit_up_1.iloc[:,1:].apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
    for i in range(len(start_list_edit3)):
        nb1 = sit_up_1.iloc[start_list_edit3[i]:end_listd_edit3[i]]
        nb1_ = nb1.copy()
        nb1_.loc[:,"Time"] = np.arange(1,nb1.shape[0]+1)
        nb1_.reset_index(drop = True)
        slice_list.append(nb1_)
    sliced_sample = pd.concat(slice_list)
    sliced_sample["label"] = label # 0是不标准。1是标准
    return sliced_sample.reset_index(drop = True)

# %%
raw_csv_to_sliced_sample("lefthand_normal_2.csv",1)
# Out:
#       Time       og1       og2       og3       ag1       ag2       ag3  \
# 0        1  0.400840  0.558949  0.442415  0.026570  0.044834  0.121325
# 1        2  0.400840  0.558949  0.442415  0.026570  0.044527  0.121310
# 2        3  0.397441  0.550766  0.444582  0.026570  0.044405  0.121295
# 3        4  0.397441  0.550766  0.444582  0.026555  0.044589  0.121280
# 4        5  0.390444  0.547885  0.446440  0.026494  0.044772  0.121264
# ...    ...       ...       ...       ...       ...       ...       ...
# 3811   442  0.382647  0.556068  0.442105  0.013507  0.115269  0.480005
# 3812   443  0.376449  0.554109  0.441486  0.013308  0.115085  0.479777
# 3813   444  0.376449  0.554109  0.441486  0.013110  0.114902  0.479548
# 3814   445  0.378449  0.552149  0.440557  0.012927  0.114779  0.479319
# 3815   446  0.378449  0.552149  0.440557  0.012743  0.114718  0.479105
#
#            ac1       ac2       ac3  label
# 0     0.935061  0.825214  0.853282      1
# 1     0.935061  0.825214  0.853282      1
# 2     0.935284  0.823932  0.851448      1
# 3     0.935284  0.823932  0.851448      1
# 4     0.934391  0.822009  0.849248      1
# ...        ...       ...       ...    ...
# 3811  0.924486  0.837607  0.856619      1
# 3812  0.924263  0.838390  0.856179      1
# 3813  0.924263  0.838390  0.856179      1
# 3814  0.924188  0.839103  0.855042      1
# 3815  0.924188  0.839103  0.855042      1
#
# [3816 rows x 11 columns]

# %% [markdown]
# # 遍历所有文件

# %%
filename_list = ["lefthand_abnormal_1.csv","lefthand_abnormal_2.csv",
                 "lefthand_normal_1.csv","lefthand_normal_2.csv","lefthand_normal_4.csv","lefthand_normal_5.csv"]
label_list = [0,0,1,1,1,1]

# %%
sliced_sample_list = []
for file,label in zip(filename_list,label_list):
    sliced_sample_list.append(raw_csv_to_sliced_sample(file,label))

# %%
sit_up_train = pd.concat(sliced_sample_list).reset_index(drop= True)
sit_up_train
# Out:
#        Time       og1       og2       og3       ag1       ag2       ag3  \
# 0         1  0.518356  0.522703  0.477941  0.009946  0.003192  0.532673
# 1         2  0.518481  0.522598  0.477941  0.009946  0.003263  0.532673
# 2         3  0.518481  0.522598  0.477941  0.009946  0.003263  0.532673
# 3         4  0.518607  0.522598  0.477941  0.009946  0.003334  0.532673
# 4         5  0.518607  0.522598  0.477941  0.009946  0.003334  0.532673
# ...     ...       ...       ...       ...       ...       ...       ...
# 21901   363  0.272828  0.510296  0.529471  0.022552  0.190653  0.641418
# 21902   364  0.282271  0.501676  0.528124  0.021120  0.190908  0.641418
# 21903   365  0.282271  0.501676  0.528124  0.019666  0.191163  0.641418
# 21904   366  0.299600  0.494110  0.525261  0.018651  0.191930  0.641479
# 21905   367  0.299600  0.494110  0.525261  0.017612  0.192696  0.641540
#
#             ac1       ac2       ac3  label
# 0      0.788878  0.931258  0.879269      0
# 1      0.788878  0.931258  0.879386      0
# 2      0.788878  0.931258  0.879386      0
# 3      0.788806  0.931180  0.879425      0
# 4      0.788806  0.931180  0.879425      0
# ...         ...       ...       ...    ...
# 21901  0.276848  0.807467  0.838980      1
# 21902  0.277860  0.811052  0.836329      1
# 21903  0.277860  0.811052  0.836329      1
# 21904  0.278319  0.813644  0.842500      1
# 21905  0.278319  0.813644  0.842500      1
#
# [21906 rows x 11 columns]
